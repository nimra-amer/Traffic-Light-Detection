# %%
import matplotlib.pyplot as plt

categories = ['Logistic Regression', 'YOLO']
values = [69.28 , 80.22 ]

plt.bar(categories, values)
plt.title('Accuracy Comparison for Normalization')
plt.show()

# %%
categories = ['Logistic Regression', 'YOLO']
values = [39.7042093287827 , 85.603849]

plt.bar(categories, values)
plt.title('Accuracy Comparison for Anchor Boxs')
plt.show()

# %%
categories = ['Logistic Regression', 'YOLO']
values = [80.00 , 88.58798]

plt.bar(categories, values)
plt.title('Accuracy Comparison for Augumented Images')
plt.show()
